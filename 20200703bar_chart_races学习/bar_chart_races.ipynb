# %% [markdown]
# # bar_chart_race_cn库
# 使用bar_chart_race_cn绘制bar chart races图,
#
# ### 官方文档
# bar_chart_race_cn是对bar_chart_race库的汉化版，具体文档可查看原创作者的文档
#
# https://www.dexplo.org/bar_chart_race
#
#
# ### 安装
# ```
# pip install bar_chart_race_cn
# ```

# %% [markdown]
# # 快速上手
# ### 可视化

# %%
import bar_chart_race_cn as bcr

bcr.bar_chart_race(df=df,
                   filename='近20年各省财政收入.mp4',
                   title='近20年各省财政收入(单位: 亿元)'
                  )

# %% [markdown]
# ### 数据准备
# 数据自国家统计局，以**财政收入.csv**

# %%
import pandas as pd

df = pd.read_csv('data/财政收入.csv')

def year2timestamp(year):
    #转为可比较大小的日期格式
    return pd.Timestamp(str(year))

#把year转化为可比较日期大小的行索引index
df['year'] = df['year'].apply(year2timestamp)
df.set_index('year', inplace=True)
df.sort_index(inplace=True)
df.head(5)
# Out:
#                北京市     天津市     河北省     山西省  内蒙古自治区     辽宁省     吉林省    黑龙江省  \
# year
# 2000-01-01  345.00  133.61  248.76  114.48   95.03  295.63  103.83  185.34
# 2001-01-01  454.17  163.64  283.50  132.76   99.43  370.44  121.10  213.64
# 2002-01-01  533.99  209.70  302.31  150.82  112.85  399.69  131.49  231.89
# 2003-01-01  592.54  204.53  335.83  186.05  138.72  447.05  154.00  248.86
# 2004-01-01  744.49  246.18  407.83  256.36  196.76  529.64  166.28  289.42
#
#                 上海市     江苏省  ...     重庆市     四川省     贵州省     云南省  西藏自治区  \
# year                         ...
# 2000-01-01   485.38  448.31  ...   87.24  233.86   85.23  180.75   5.38
# 2001-01-01   609.47  572.15  ...  106.12  271.12   99.75  191.28   6.11
# 2002-01-01   719.79  643.70  ...  157.87  291.87  108.28  206.76   7.31
# 2003-01-01   886.23  798.11  ...  161.56  336.59  124.56  229.00   8.15
# 2004-01-01  1106.19  980.49  ...  200.62  385.78  149.29  263.36  10.02
#
#                陕西省     甘肃省    青海省  宁夏回族自治区  新疆维吾尔自治区
# year
# 2000-01-01  114.97   61.28  16.58    20.82     79.07
# 2001-01-01  135.81   69.95  19.82    27.57     95.09
# 2002-01-01  150.29   76.24  21.10    26.47    116.47
# 2003-01-01  177.33   87.66  24.04    30.03    128.22
# 2004-01-01  214.96  104.16  27.00    37.47    155.70
#
# [5 rows x 31 columns]

# %% [markdown]
# ### 可视化

# %%
import bar_chart_race_cn as bcr

bcr.bar_chart_race(df=df,
                   filename='近20年各省财政收入.mp4',
                   title='近20年各省财政收入(单位: 亿元)'
                  )
