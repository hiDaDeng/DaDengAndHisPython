# %% [markdown]
# <d p="0,1,25,16777215,1312863760,0,eff85771,42759017">前排占位置</d>
#
# 这行内容的意义呢
# 先说内容“前排站位置”就不解释了
# p这个字段里面的内容：
# 0,1,25,16777215,1312863760,0,eff85771,42759017
# 中几个逗号分割的数据
#
# - **第一个参数是弹幕出现的时间 以秒数为单位。**
# - 第二个参数是弹幕的模式1..3 滚动弹幕 4底端弹幕 5顶端弹幕 6.逆向弹幕 7精准定位 8高级弹幕
# - 第三个参数是字号， 12非常小,16特小,18小,25中,36大,45很大,64特别大
# - 第四个参数是字体的颜色 以HTML颜色的十位数为准
# - 第五个参数是Unix格式的时间戳。基准时间为 1970-1-1 08:00:00
# - 第六个参数是弹幕池 0普通池 1字幕池 2特殊池 【目前特殊池为高级弹幕专用】
# - **第七个参数是发送者的ID，用于“屏蔽此弹幕的发送者”功能**
# - 第八个参数是弹幕在弹幕数据库中rowID 用于“历史弹幕”功能。

# %%
import requests
from pyquery import PyQuery
import csv

# 新建csv文件
csvf = open('弹幕.csv', 'a+', encoding='gbk', newline='')
writer = csv.writer(csvf)
writer.writerow(('Date', 'Chapter', 'VideoTime', 'SenderId', 'DanMuContent'))

#伪装访问使用的参数，防止被封锁
cookies = {"Cookie": "LIVE_BUVID=AUTO8615712789659549; sid=jsfj6oqh; CURRENT_FNVAL=16; stardustvideo=1; rpdid=|(JY))RmR~|k0J'ul~uR)Y~Rm; im_notify_type_122592901=0; _uuid=CBCB2501-993C-6BA6-4F52-69D7AEC5194C49130infoc; DedeUserID=122592901; DedeUserID__ckMd5=8ee93e9872d7be92; SESSDATA=7b9851ab%2C1579351871%2C33bb73c1; bili_jct=16e170a7111b40a9d5d367c0672a74ea; CURRENT_QUALITY=32; INTVER=1; bp_t_offset_122592901=339892025202184308; stardustpgcv=0606"}
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/79.0.3945.88 Safari/537.36'}

# 构建网址url
oid = 139531860#139530292#139527441
chapter = 3
date='2020-01-03'
template = 'https://api.bilibili.com/x/v2/dm/history?type=1&oid={oid}&date={date}'
url = template.format(date=date, oid=oid)

# 访问
resp = requests.get(url, headers=headers, cookies=cookies)
resp.encoding='utf-8'

# 解析定位数据+保存输出
doc = PyQuery(resp.content)
for item in doc.items('d'):
    danmu = item.text()
    attr = item.attr('p')
    videotime = attr.split(',')[0]
    senderid = attr.split(',')[-2]
    print(videotime, senderid, danmu)
    writer.writerow((date, chapter, videotime, senderid, danmu))
    #print(danmu, attr)
  

csvf.close()
# Out:
# 4010.34000 24eb222e 哔哩哔哩干杯
# 2579.66100 4ed91032 2.0变成魔鬼哈哈啥
# 463.74500 65135039 观众在河底的别跑
# 1176.78800 576390e1 握草
# 705.49000 a8f8db8a 神仙上场
# 2271.52200 3bc5ec6c 。。。。。。。。。。。。。。。。。。。。。。。。。。。。
# 17.27100 c82bb67a 小破炸牛逼！！！
# 4416.34300 51cf0cc6 多谢款待
# 44.50000 4f8f1833 哈利波特！
# 358.47900 1c3229ec 老婆
# 2156.84500 e5102376 10:39
# 3667.53200 58b00c0c 2020第一场演唱会啊，哈哈哈
# 742.27800 9d11ed97 我的最爱
# 892.04900 635e4c72 哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈或
# 3253.82200 1e67e4f7 要这币有何用 都想给小破站
# 65.38600 1fff3188 我靠！！！
# 78.34400 2a68f483 把指挥棒给我换成魔杖
# 3145.57700 44e25158 新年快乐
# 4023.15900 22baaa25 哔哩哔哩乾杯～(￣▽￣～)~
# 262.91100 dca599a5 帅
# 63.86600 1fff3188 拉文克劳！！！！
# 4256.22900 e3f7a161 bilibili- ( ゜- ゜)つロ 乾杯~
# 4404.05200 ac50e5d3 2020，一切都是最好的安排
# 1264.29200 d185c130 now who is the joker of 班集体no
# 4444.80400 377c6462 多谢款待
# 909.25600 d2909e37 所有能发声的东西感觉都玩得转
# 396.84700 7fe858d9 wawawawa
# 2442.20300 b5b7aff0 你看这个面
# 2272.08400 88443fa2 。。。。。。。。。。。。。。。。。。。。。。。。。。。。。。。。。。。。。。。。。。。。。。。。
# ...

# %%
# Out:
# 1857.66700 c3184765 luanru
# 2289.44400 54af541e 别黑我小破站的一员
# 2430.12200 f931b493 狗儿你来啦
# 2336.26100 230997f0 吸吸吸吸吸吸吸吸吸吸吸吸吸 ， 吸吸吸吸吸吸吸吸吸
# 3581.05800 4516fcba 德玛西亚
# 81.41900 349fa9f9 补课
# 987.29900 f28bc011 2号晚上11点 4号过20岁生日
# 2801.74800 c9b3b069 啊啊啊啊啊啊啊啊啊啊啊啊
# 3619.29500 3bed3da 无畏先锋
# 3382.79900 149a72d4 云飞兄，别来无恙
# 1678.09900 d55dddb 东北电力的别走
# 3146.38900 64244204 红啦
# 55.29900 c25a0c0e 这一切都是命运石之门的选择
# 3318.97300 e74539ac 狭路相逢勇者胜
# 1697.10900 d7783793 广东财经大学华商学院
# 956.20400 151c700a 我是莲花白
# 2754.67900 185f7e7b 鲁E的在这
# 194.23800 4d71462d 看到兽人再听到兽人喘息的声音 太精良了的晚会
# 3203.32600 d258cf65 啊啊啊啊啊啊
# 2586.15300 aaaa8452 来了又来了
# 2167.37700 2f2ddd0c 尊重台上每一个人
# 2039.61400 9895ba3a 你要的原谅
# 193.67200 8df23f00 为了部落！！！
# 2767.95000 c1a4f960 赣B发车
# 3526.23800 d990e1f9 现场安利
# 1657.54000 a2c77b97 甘肃财贸职业学院
# 3139.33500 54baae46 红
# 3559.66800 2f127069 暗影岛冲锋
# 1053.58500 ad650640 杰尼龟
# 2840.21200 d6b6804e 太牛了
# 9.79900 2c4cd8f6 来补课了
# 3275.10300 473f0c98 此生无悔入华夏，来世还愿种花家
# 1054.42600 e4de8580 不枉魂魄入华夏
# ...

# %%
import requests
from pyquery import PyQuery
import csv

# 新建csv文件
csvf = open('弹幕.csv', 'a+', encoding='gbk', newline='')
writer = csv.writer(csvf)
writer.writerow(('Date', 'Chapter', 'VideoTime', 'SenderId', 'DanMuContent'))

#伪装访问使用的参数，防止被封锁
cookies = {"Cookie": "LIVE_BUVID=AUTO8615712789659549; sid=jsfj6oqh; CURRENT_FNVAL=16; stardustvideo=1; rpdid=|(JY))RmR~|k0J'ul~uR)Y~Rm; im_notify_type_122592901=0; _uuid=CBCB2501-993C-6BA6-4F52-69D7AEC5194C49130infoc; DedeUserID=122592901; DedeUserID__ckMd5=8ee93e9872d7be92; SESSDATA=7b9851ab%2C1579351871%2C33bb73c1; bili_jct=16e170a7111b40a9d5d367c0672a74ea; CURRENT_QUALITY=32; INTVER=1; bp_t_offset_122592901=339892025202184308; stardustpgcv=0606"}
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/79.0.3945.88 Safari/537.36'}

# 构建网址url
oid = 139531860#139530292#139527441
chapter = 3
date='2020-01-03'
template = 'https://api.bilibili.com/x/v2/dm/history?type=1&oid={oid}&date={date}'
url = template.format(date=date, oid=oid)

# 访问
resp = requests.get(url, headers=headers, cookies=cookies)
resp.encoding='utf-8'

# 解析定位数据+保存输出
doc = PyQuery(resp.content)
for item in doc.items('d'):
    danmu = item.text()
    attr = item.attr('p')
    videotime = attr.split(',')[0]
    senderid = attr.split(',')[-2]
    print(videotime, senderid, danmu)
    writer.writerow((date, chapter, videotime, senderid, danmu))
    #print(danmu, attr)
  

csvf.close()
