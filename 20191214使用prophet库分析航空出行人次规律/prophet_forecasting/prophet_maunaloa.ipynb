# %%
import pandas as pd
from fbprophet import Prophet
from fbprophet.plot import add_changepoints_to_plot
from fbprophet.diagnostics import cross_validation
from fbprophet.diagnostics import performance_metrics
from fbprophet.plot import plot_cross_validation_metric
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('data/co2-ppm-daily_csv.csv')

# %%
data.head()
# Out:
#          date   value
# 0  1958-03-30  316.16
# 1  1958-03-31  316.40
# 2  1958-04-02  317.67
# 3  1958-04-03  317.76
# 4  1958-04-04  317.09

# %%
df = pd.DataFrame()
df['ds'] = pd.to_datetime(data['date'])
df['y'] = data['value']

# %%
prophet = Prophet()

prophet.add_country_holidays(country_name='US')
prophet.fit(df)
future = prophet.make_future_dataframe(periods=1095)
forecast = prophet.predict(future)
fig = prophet.plot(forecast)
a = add_changepoints_to_plot(fig.gca(), prophet, forecast)
plt.show()
fig2 = prophet.plot_components(forecast)
plt.show()
# Out:
# INFO:numexpr.utils:NumExpr defaulting to 4 threads.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
prophet = Prophet()

prophet.fit(df)
future = prophet.make_future_dataframe(periods=120, freq='m')
forecast = prophet.predict(future)
fig = prophet.plot(forecast)
a = add_changepoints_to_plot(fig.gca(), prophet, forecast)
plt.show()
fig2 = prophet.plot_components(forecast)
plt.show()
# Out:
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
prophet = Prophet(changepoint_prior_scale=.1)

prophet.fit(df)
future = prophet.make_future_dataframe(periods=240, freq='m')
forecast = prophet.predict(future)
fig = prophet.plot(forecast)
a = add_changepoints_to_plot(fig.gca(), prophet, forecast)
plt.show()
fig2 = prophet.plot_components(forecast)
plt.show()
# Out:
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
prophet = Prophet(weekly_seasonality=False,
                  changepoint_prior_scale=.001)

prophet.fit(df)
future = prophet.make_future_dataframe(periods=240, freq='m')
forecast = prophet.predict(future)
fig = prophet.plot(forecast)
a = add_changepoints_to_plot(fig.gca(), prophet, forecast)
plt.show()
fig2 = prophet.plot_components(forecast)
plt.show()
# Out:
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
prophet = Prophet(weekly_seasonality=False,
                  changepoint_prior_scale=.00001)

prophet.fit(df)
future = prophet.make_future_dataframe(periods=240, freq='m')
forecast = prophet.predict(future)
fig = prophet.plot(forecast)
a = add_changepoints_to_plot(fig.gca(), prophet, forecast)
plt.show()
fig2 = prophet.plot_components(forecast)
plt.show()
# Out:
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Optimization terminated abnormally. Falling back to Newton.
