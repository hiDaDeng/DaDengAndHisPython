# %%
import pandas as pd
from fbprophet import Prophet
from fbprophet.plot import add_changepoints_to_plot
from fbprophet.diagnostics import cross_validation
from fbprophet.diagnostics import performance_metrics
from fbprophet.plot import plot_cross_validation_metric
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('data/divvy_data.csv')

# %%
data.head()
# Out:
#    trip_id  year  month  week  day  hour    usertype  gender  \
# 0  2355134  2014      6    27    0    23  Subscriber    Male
# 1  2355133  2014      6    27    0    23  Subscriber    Male
# 2  2355130  2014      6    27    0    23  Subscriber    Male
# 3  2355129  2014      6    27    0    23  Subscriber  Female
# 4  2355128  2014      6    27    0    23  Subscriber  Female
#
#              starttime             stoptime  ...  from_station_id  \
# 0  2014-06-30 23:57:00  2014-07-01 00:07:00  ...              131
# 1  2014-06-30 23:56:00  2014-07-01 00:00:00  ...              282
# 2  2014-06-30 23:33:00  2014-06-30 23:35:00  ...              327
# 3  2014-06-30 23:26:00  2014-07-01 00:24:00  ...              134
# 4  2014-06-30 23:16:00  2014-06-30 23:26:00  ...              320
#
#              from_station_name latitude_start  longitude_start  \
# 0    Lincoln Ave & Belmont Ave      41.939365       -87.668385
# 1      Halsted St & Maxwell St      41.864580       -87.646930
# 2  Sheffield Ave & Webster Ave      41.921687       -87.653714
# 3     Peoria St & Jackson Blvd      41.877749       -87.649633
# 4     Loomis St & Lexington St      41.872187       -87.661501
#
#   dpcapacity_start  to_station_id           to_station_name  latitude_end  \
# 0             15.0            303   Broadway & Cornelia Ave     41.945512
# 1             15.0             22        May St & Taylor St     41.869482
# 2             19.0            225  Halsted St & Dickens Ave     41.919936
# 3             19.0            194      State St & Wacker Dr     41.887155
# 4             15.0            134  Peoria St & Jackson Blvd     41.877749
#
#    longitude_end dpcapacity_end
# 0     -87.645980           15.0
# 1     -87.655486           15.0
# 2     -87.648830           15.0
# 3     -87.627750           11.0
# 4     -87.649633           19.0
#
# [5 rows x 23 columns]

# %%
data['date'] = pd.to_datetime(data['starttime']).dt.round('H')
d = data.groupby('date')['events'].agg({lambda x: x.value_counts().index[0]})
d['rides'] = data.groupby('date')['starttime'].count()
d['temperature'] = data.groupby('date')['temperature'].mean()
d.rename(columns={'<lambda>': 'weather'}, inplace=True)
d.reset_index(level=0, inplace=True)

# %%
d.head()
# Out:
#                  date       weather  rides  temperature
# 0 2014-01-01 01:00:00     not clear      1         10.9
# 1 2014-01-01 02:00:00     not clear      9         10.9
# 2 2014-01-01 03:00:00     not clear      4         13.0
# 3 2014-01-01 04:00:00     not clear      1         14.0
# 4 2014-01-01 07:00:00  rain or snow      2         16.1

# %%
d.tail()
# Out:
#                      date weather  rides  temperature
# 34711 2017-12-31 20:00:00   clear     10        1.900
# 34712 2017-12-31 21:00:00   clear      9        1.900
# 34713 2017-12-31 22:00:00   clear      3        0.000
# 34714 2017-12-31 23:00:00   clear      8       -0.225
# 34715 2018-01-01 00:00:00   clear      5       -0.900

# %%
d.weather.unique()
# Out:
# array(['not clear', 'rain or snow', 'clear', 'cloudy', 'tstorms',
#        'unknown'], dtype=object)

# %%
d.weather.value_counts()
# Out:
# cloudy          27604
# rain or snow     3358
# clear            3106
# not clear         372
# tstorms           275
# unknown             1
# Name: weather, dtype: int64

# %%
plt.figure(figsize=(10, 7))
plt.scatter(x=d['date'], y=d['temperature'], s=1)
plt.show()

# %%
plt.figure(figsize=(10, 7))
plt.scatter(d.date, d.rides, s=1)
plt.show()

# %%
df = pd.DataFrame()
df['ds'] = d['date']
df['y'] = d['rides']
df['temp'] = d['temperature']
df = pd.concat([df, pd.get_dummies(d['weather'], drop_first=True)], axis=1)
df['cap'] = 15000
df['floor'] = 0

# %%
df.head()
# Out:
#                    ds  y  temp  cloudy  not clear  rain or snow  tstorms  \
# 0 2014-01-01 01:00:00  1  10.9       0          1             0        0
# 1 2014-01-01 02:00:00  9  10.9       0          1             0        0
# 2 2014-01-01 03:00:00  4  13.0       0          1             0        0
# 3 2014-01-01 04:00:00  1  14.0       0          1             0        0
# 4 2014-01-01 07:00:00  2  16.1       0          0             1        0
#
#    unknown    cap  floor
# 0        0  15000      0
# 1        0  15000      0
# 2        0  15000      0
# 3        0  15000      0
# 4        0  15000      0

# %%
df.tail()
# Out:
#                        ds   y   temp  cloudy  not clear  rain or snow  \
# 34711 2017-12-31 20:00:00  10  1.900       0          0             0
# 34712 2017-12-31 21:00:00   9  1.900       0          0             0
# 34713 2017-12-31 22:00:00   3  0.000       0          0             0
# 34714 2017-12-31 23:00:00   8 -0.225       0          0             0
# 34715 2018-01-01 00:00:00   5 -0.900       0          0             0
#
#        tstorms  unknown    cap  floor
# 34711        0        0  15000      0
# 34712        0        0  15000      0
# 34713        0        0  15000      0
# 34714        0        0  15000      0
# 34715        0        0  15000      0

# %%
df.describe()
# Out:
#                   y          temp        cloudy     not clear  rain or snow  \
# count  34716.000000  34716.000000  34716.000000  34716.000000  34716.000000
# mean     273.511781     51.241300      0.795138      0.010716      0.096728
# std      326.690929     20.695271      0.403607      0.102961      0.295591
# min        1.000000    -15.000000      0.000000      0.000000      0.000000
# 25%       36.000000     35.664567      1.000000      0.000000      0.000000
# 50%      155.000000     52.672934      1.000000      0.000000      0.000000
# 75%      397.000000     68.582418      1.000000      0.000000      0.000000
# max     2149.000000     94.530645      1.000000      1.000000      1.000000
#
#             tstorms       unknown      cap    floor
# count  34716.000000  34716.000000  34716.0  34716.0
# mean       0.007921      0.000029  15000.0      0.0
# std        0.088650      0.005367      0.0      0.0
# min        0.000000      0.000000  15000.0      0.0
# 25%        0.000000      0.000000  15000.0      0.0
# 50%        0.000000      0.000000  15000.0      0.0
# 75%        0.000000      0.000000  15000.0      0.0
# max        1.000000      1.000000  15000.0      0.0

# %%
df[df['ds'] < pd.to_datetime('2017')].head()
# Out:
#                    ds  y  temp  cloudy  not clear  rain or snow  tstorms  \
# 0 2014-01-01 01:00:00  1  10.9       0          1             0        0
# 1 2014-01-01 02:00:00  9  10.9       0          1             0        0
# 2 2014-01-01 03:00:00  4  13.0       0          1             0        0
# 3 2014-01-01 04:00:00  1  14.0       0          1             0        0
# 4 2014-01-01 07:00:00  2  16.1       0          0             1        0
#
#    unknown    cap  floor
# 0        0  15000      0
# 1        0  15000      0
# 2        0  15000      0
# 3        0  15000      0
# 4        0  15000      0

# %%
m = Prophet()
m.add_country_holidays(country_name='US')
m.fit(df[d['date'] < pd.to_datetime('2017-01-01')])
future = m.make_future_dataframe(periods=365 * 24, freq='h')
forecast = m.predict(future)
# Out:
# INFO:numexpr.utils:NumExpr defaulting to 4 threads.

# %%
fig1 = m.plot(forecast)

# %%
fig2 = m.plot_components(forecast)

# %%
a = add_changepoints_to_plot(m.plot(forecast).gca(), m, forecast)

# %%
#dataframe of annual US Public Holidays over training and forecasting periods 

ny = pd.DataFrame({'holiday': "New Year's Day",
                   'ds' : pd.to_datetime(['2014-01-01',
                                          '2015-01-01',
                                          '2016-01-01',
                                          '2017-01-01',
                                          '2018-01-01',
                                          '2019-01-01'])})  
mlk = pd.DataFrame({'holiday': 'Birthday of Martin Luther King, Jr.',
                    'ds' : pd.to_datetime(['2014-01-20',
                                           '2015-01-19',
                                           '2016-01-18',
                                           '2017-01-16',
                                           '2018-01-15',
                                           '2019-01-21'])}) 
wash = pd.DataFrame({'holiday': "Washington's Birthday",
                     'ds' : pd.to_datetime(['2014-02-17',
                                            '2015-02-16',
                                            '2016-02-15',
                                            '2017-02-20',
                                            '2018-02-19',
                                            '2019-02-18'])})
mem = pd.DataFrame({'holiday': 'Memorial Day',
                    'ds' : pd.to_datetime(['2014-05-26',
                                           '2015-05-25',
                                           '2016-05-30',
                                           '2017-05-29',
                                           '2018-05-28',
                                           '2019-05-27'])})
ind = pd.DataFrame({'holiday': 'Independence Day',
                    'ds' : pd.to_datetime(['2014-07-04',
                                           '2015-07-04',
                                           '2016-07-04',
                                           '2017-07-04',
                                           '2018-07-04',
                                           '2019-07-04'])})
lab = pd.DataFrame({'holiday': 'Labor Day',
                    'ds' : pd.to_datetime(['2014-09-01',
                                           '2015-09-07',
                                           '2016-09-05',
                                           '2017-09-04',
                                           '2018-09-03',
                                           '2019-09-02'])})
col = pd.DataFrame({'holiday': 'Columbus Day',
                    'ds' : pd.to_datetime(['2014-10-13',
                                           '2015-10-12',
                                           '2016-10-10',
                                           '2017-10-09',
                                           '2018-10-08',
                                           '2019-10-14'])})
vet = pd.DataFrame({'holiday': "Veteran's Day",
                    'ds' : pd.to_datetime(['2014-11-11',
                                           '2015-11-11',
                                           '2016-11-11',
                                           '2017-11-11',
                                           '2018-11-11',
                                           '2019-11-11'])})
thanks = pd.DataFrame({'holiday': 'Thanksgiving Day',
                       'ds' : pd.to_datetime(['2014-11-27',
                                              '2015-11-26',
                                              '2016-11-24',
                                              '2017-11-23',
                                              '2018-11-22',
                                              '2019-11-28']),
                       'lower_window': 0,
                       'upper_window': 1})
christ = pd.DataFrame({'holiday': 'Christmas',
                       'ds' : pd.to_datetime(['2014-12-25',
                                              '2015-12-25',
                                              '2016-12-25',
                                              '2017-12-25',
                                              '2018-12-25',
                                              '2019-12-25']),
                       'lower_window': -1,
                       'upper_window': 0})

holidays = pd.concat([ny, mlk, wash, mem, ind, lab, col, vet, thanks, christ], sort=False)

# %%
prophet = Prophet(yearly_seasonality=False,
                  changepoint_prior_scale=.001).add_seasonality(name='yearly',
                                    period=365.25,
                                    fourier_order=3,
                                    prior_scale=10,
                                    mode='additive')


prophet.add_country_holidays(country_name='US')
prophet.fit(df[df['ds'] < pd.to_datetime('2017')])
future = prophet.make_future_dataframe(periods=365 * 24, freq='H')



forecast = prophet.predict(future)
fig = prophet.plot(forecast)
a = add_changepoints_to_plot(fig.gca(), prophet, forecast)
plt.show()
fig2 = prophet.plot_components(forecast)
plt.show()
df_cv = cross_validation(prophet, initial='730 days', period='180 days', horizon = '365 days')
df_p = performance_metrics(df_cv)
fig = plot_cross_validation_metric(df_cv, metric='mape')
plt.show()
print('mape:', '{:.2f}%'.format(100 * df_p['mape'].mean()))
# Out:
# INFO:fbprophet:Making 1 forecasts with cutoffs between 2016-01-01 23:00:00 and 2016-01-01 23:00:00
# mape: 315.91%

# %%
prophet = Prophet(growth='linear',
                  n_changepoints=10,
                  yearly_seasonality=False,
                  weekly_seasonality=False,
                  daily_seasonality=False,
                  holidays=holidays,
                  seasonality_mode='additive',
                  seasonality_prior_scale=10,
                  holidays_prior_scale=10,
                  changepoint_prior_scale=.05,
                  mcmc_samples=0
                 ).add_seasonality(name='yearly',
                                    period=365.25,
                                    fourier_order=3,
                                    prior_scale=10,
                                    mode='additive'
                  ).add_seasonality(name='weekly',
                                    period=7,
                                    fourier_order=5,
                                    prior_scale=10,
                                    mode='additive'
                  ).add_seasonality(name='daily',
                                    period=1,
                                    fourier_order=4,
                                    prior_scale=.10,
                                    mode='additive'
                  )

prophet.add_country_holidays(country_name='US')

prophet.add_regressor('temp')
prophet.add_regressor('cloudy')
prophet.add_regressor('not clear')
prophet.add_regressor('rain or snow')
prophet.add_regressor('tstorms')
prophet.add_regressor('unknown')

prophet.fit(df[df['ds'] < pd.to_datetime('2017')])
future = prophet.make_future_dataframe(periods=365 * 24, freq='H')

future['temp'] = df['temp']
future['cloudy'] = df['cloudy']
future['not clear'] = df['not clear']
future['rain or snow'] = df['rain or snow']
future['tstorms'] = df['tstorms']
future['unknown'] = df['unknown']

future.dropna(inplace=True)

forecast = prophet.predict(future)
fig = prophet.plot(forecast)
a = add_changepoints_to_plot(fig.gca(), prophet, forecast)
plt.show()
fig2 = prophet.plot_components(forecast)
plt.show()
df_cv = cross_validation(prophet, initial='730 days', period='180 days', horizon='365 days')
df_p = performance_metrics(df_cv)
fig = plot_cross_validation_metric(df_cv, metric='mape')
plt.show()
print('mape:', '{:.2f}%'.format(100 * df_p['mape'].mean()))
# Out:
# INFO:fbprophet:Making 1 forecasts with cutoffs between 2016-01-01 23:00:00 and 2016-01-01 23:00:00
# mape: 383.50%

# %%
prophet = Prophet(growth='linear',
                  n_changepoints=10,
                  yearly_seasonality=False,
                  weekly_seasonality=False,
                  daily_seasonality=False,
                  holidays=holidays,
                  seasonality_mode='additive',
                  seasonality_prior_scale=10,
                  holidays_prior_scale=10,
                  changepoint_prior_scale=.05,
                  mcmc_samples=0
                 ).add_seasonality(name='yearly',
                                    period=365.25,
                                    fourier_order=3,
                                    prior_scale=10,
                                    mode='additive'
                  ).add_seasonality(name='weekly',
                                    period=7,
                                    fourier_order=5,
                                    prior_scale=.1,
                                    mode='additive'
                  ).add_seasonality(name='daily',
                                    period=1,
                                    fourier_order=4,
                                    prior_scale=.1,
                                    mode='additive'
                  )

prophet.add_country_holidays(country_name='US')

prophet.add_regressor('temp')
prophet.add_regressor('cloudy')
prophet.add_regressor('not clear')
prophet.add_regressor('rain or snow')
prophet.add_regressor('tstorms')
prophet.add_regressor('unknown')

prophet.fit(df[df['ds'] < pd.to_datetime('2017')])
future = prophet.make_future_dataframe(periods=365 * 24, freq='H')

future['temp'] = df['temp']
future['cloudy'] = df['cloudy']
future['not clear'] = df['not clear']
future['rain or snow'] = df['rain or snow']
future['tstorms'] = df['tstorms']
future['unknown'] = df['unknown']

future.dropna(inplace=True)

forecast = prophet.predict(future)
fig = prophet.plot(forecast)
a = add_changepoints_to_plot(fig.gca(), prophet, forecast)
plt.show()
fig2 = prophet.plot_components(forecast)
plt.show()
df_cv = cross_validation(prophet, initial='730 days', period='180 days', horizon='365 days')
df_p = performance_metrics(df_cv)
fig = plot_cross_validation_metric(df_cv, metric='mape')
plt.show()
print('mape:', '{:.2f}%'.format(100 * df_p['mape'].mean()))
# Out:
# INFO:fbprophet:Making 1 forecasts with cutoffs between 2016-01-01 23:00:00 and 2016-01-01 23:00:00
# mape: 376.55%

# %%
prophet = Prophet()
prophet.add_country_holidays(country_name='US')
prophet.fit(df[df['ds'] < pd.to_datetime('2017')])
future = prophet.make_future_dataframe(periods=365, freq='D')
forecast = prophet.predict(future)
fig = prophet.plot(forecast)
a = add_changepoints_to_plot(fig.gca(), prophet, forecast)
plt.show()
fig2 = prophet.plot_components(forecast)
plt.show()
df_cv = cross_validation(prophet, initial='730 days', period='180 days', horizon = '365 days')
df_p = performance_metrics(df_cv)
fig = plot_cross_validation_metric(df_cv, metric='mape')
plt.show()
print('mape:', '{:.2f}%'.format(100 * df_p['mape'].mean()))
# Out:
# INFO:fbprophet:Making 1 forecasts with cutoffs between 2016-01-01 23:00:00 and 2016-01-01 23:00:00
# mape: 309.23%

# %%
prophet = Prophet(growth='linear',
                  n_changepoints=25,
                  changepoint_range=0.8,
                  yearly_seasonality=True,
                  weekly_seasonality=True,
                  daily_seasonality=False,
                  holidays=holidays,
                  seasonality_mode='additive',
                  seasonality_prior_scale=10,
                  holidays_prior_scale=10,
                  changepoint_prior_scale=.01,
                  mcmc_samples=0)
prophet.add_country_holidays(country_name='US')
prophet.add_regressor('temp', mode='additive')
prophet.add_regressor('cloudy', mode='additive')
prophet.add_regressor('not clear', mode='additive')
prophet.add_regressor('rain or snow', mode='additive')
prophet.fit(df[df['ds'] < pd.to_datetime('2017')])
future = prophet.make_future_dataframe(periods=365, freq='D')
future['temp'] = df['temp']
future['cloudy'] = df['cloudy']
future['not clear'] = df['not clear']
future['rain or snow'] = df['rain or snow']
future['cap'] = df['cap']
forecast = prophet.predict(future)
fig = prophet.plot(forecast)
a = add_changepoints_to_plot(fig.gca(), prophet, forecast)
plt.show()
fig2 = prophet.plot_components(forecast)
plt.show()
df_cv = cross_validation(prophet, initial='730 days', period='180 days', horizon = '365 days')
df_p = performance_metrics(df_cv)
fig = plot_cross_validation_metric(df_cv, metric='mape')
plt.show()
print('mape:', '{:.2f}%'.format(100 * df_p['mape'].mean()))
# Out:
# INFO:fbprophet:Making 1 forecasts with cutoffs between 2016-01-01 23:00:00 and 2016-01-01 23:00:00
# mape: 508.70%
