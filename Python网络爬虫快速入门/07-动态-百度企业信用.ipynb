# %% [markdown]
# # 实战
# 写爬虫流程：
#
# 1. 在浏览器中打开网站的某个页面
# 2. 打开开发者工具，对该网页进行刷新（查看Network信息，一般都会先点击”第二页“或者”查看更多“，试图发现规律，找到真正的网址）
# 3. 如果是html网页，那么就用Element进行页面数据定位；如果是json数据，就在network中进行数据定位
# 4. 存储数据
# 5. 让程序自动化访问多个页面，重复1-4
#
# # 实战分类
# - 静态网站：如天涯、boss直聘、大众点评
# - 动态网页：京东评论、百度企业信用等

# %% [markdown]
# # 视频讲解链接
# https://www.bilibili.com/video/av72010301/?p=8
#
# # 百度企业信用
#
# https://xin.baidu.com/

# %% [markdown]
# https://xin.baidu.com/s/l?q=%E5%8D%8E%E4%B8%BA&t=0&p=4&s=10&o=0&f=undefined
# https://xin.baidu.com/s/l?q=%E5%8D%8E%E4%B8%BA&t=0&p=5&s=10&o=0&f=undefined

# %%
import requests
import csv
import time

csvf = open('output/baidu_companys.csv', 'a+', encoding='gbk', newline='')
writer = csv.writer(csvf)
writer.writerow(('company_name', 'legalPerson', 'regCap'))

url_template = 'https://xin.baidu.com/s/l?q=%E5%8D%8E%E4%B8%BA&t=0&p={page}&s=10&o=0&f=undefined'

for page in range(1, 10):
    time.sleep(1)
    url = url_template.format(page=page)
    resp = requests.get(url)
    companys = resp.json()['data']['resultList']

    for company in companys:
        name = company['titleName']
        legalPerson = company['legalPerson']
        regCap = company['regCap']
        writer.writerow((name, legalPerson, regCap))
        print(page, name, legalPerson, regCap)
    
    
csvf.close()
# Out:
# 1 华为技术有限公司 赵明路 3,990,813.2万
# 1 华为终端有限公司 赵明路 50,000.0万
# 1 华为软件技术有限公司 张平安 50,000.0万
# 1 华为投资控股有限公司 赵明路 2,223,678.9万
# 1 华为机器有限公司 徐文伟 210,000.0万
# 1 华为技术服务有限公司 汤启兵 15,000.0万
# 1 东莞华为服务有限公司 徐文伟 20,000.0万
# 1 温州华为包装有限公司 李春波 100.0万
# 1 绍兴市华为纺织品有限公司 朱<em>华为</em> 50.0万
# 1 武汉华为投资有限公司 郭平 20,000.0万
# 2 苏州华为投资有限公司 郭平 20,000.0万
# 2 华为培训(东莞)有限公司 吕克 5,000.0万
# 2 江苏华为建设有限公司 高小静 13,500.0万
# 2 淄博华为颜料有限公司 徐博 208.0万
# 2 沂源华为投资有限公司 亓中华 3,042.7万
# 2 青岛华为帮厨有限公司 杨现芹 5,000.0万
# 2 四川华为电缆有限公司 代小勤 5,188.0万
# 2 南通华为电力设备有限公司 刘冰 5,028.0万
# 2 绍兴华为化工有限公司 王金兔 1,150.0万
# 2 华为海洋网络有限公司 郭平 3,600.0万
# 3 江苏华为项目管理有限公司 马海兰 200.0万
# 3 新泰市华为工贸有限公司 丁立斌 1,000.0万
# 3 浙江华为通信技术有限公司 傅建根 2,000.0万
# 3 广西华为投资有限公司 王建良 2,000.0万
# 3 邹平华为物资有限公司 赵功友 100.0万
# 3 磐安华为科技有限公司 应钦钟 100.0万
# 3 深圳市华为技术服务有限公司 汤启兵 2,000.0万
# 3 江西华为餐饮管理有限公司 潘昌华 2,000.0万
# 3 山东华为能源有限公司 仲伟海 1,000.0万
# 3 仁怀华为医院有限公司 虞文溢 500.0万
# 4 海南华为鲜贸易有限公司 政<em>华为</em> 1,000.0万
# 4 无锡华为建设有限公司 颜晨旭 2,018.0万
# 4 成都华为商贸有限公司 胥华 200.0万
# 4 山西华为养殖有限公司 吴利强 110.0万
# 4 温州华为机电有限公司 舒红艳 200.0万
# ...
